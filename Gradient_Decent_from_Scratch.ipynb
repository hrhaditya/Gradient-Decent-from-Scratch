# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import sklearn_pandas
import math
from math import sqrt
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split

# %%
#To read the data set
df = pd.read_csv("https://raw.githubusercontent.com/aiforsec/RIT-DSCI-633-FDS/main/Syllabus/Datasets/wisconsin-breastCancer-data.csv")
#To display the data along wiht the header
print (df.head)
# Out:
# <bound method NDFrame.head of            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
#To get the summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
#Dropped uneccessary data that wont help in predicting the value
data=df.drop(['Unnamed: 32', 'id'], axis = 1)
data.diagnosis = [1 if each == "M" else 0 for each in data.diagnosis]

# %%
#preprocess for normalization
y = data.diagnosis.values
x_data = data.drop(['diagnosis'], axis = 1)
x = (x_data - np.min(x_data))/(np.max(x_data) - np.min(x_data)).values
sklearn.preprocessing.normalize(data,norm='l2',axis=1,copy=False,return_norm=False)
# Out:
# array([[4.40545530e-04, 7.92541409e-03, 4.57286261e-03, ...,
#         1.16920784e-04, 2.02694999e-04, 5.23808636e-05],
#        [4.21281244e-04, 8.66575518e-03, 7.48616770e-03, ...,
#         7.83583113e-05, 1.15852342e-04, 3.75024563e-05],
#        [4.75707548e-04, 9.36668162e-03, 1.01087854e-02, ...,
#         1.15596934e-04, 1.71873137e-04, 4.16624671e-05],
#        ...,
#        [7.01438663e-04, 1.16438818e-02, 1.96963977e-02, ...,
#         9.94640025e-05, 1.55579096e-04, 5.48525035e-05],
#        [4.48068170e-04, 9.23020431e-03, 1.31418394e-02, ...,
#         1.18738065e-04, 1.83125461e-04, 5.55604531e-05],
#        [0.00000000e+00, 2.31098880e-02, 7.30820427e-02, ...,
#         0.00000000e+00, 8.55006294e-04, 2.09626935e-04]])

# %%
#Initializig the bias and the weight theta randomly
def initialize_weights_and_bias(dimension):
  w = 0.001
  b = 0.01

# %%
from sklearn.model_selection import train_test_split

#To add Data to X and y Variables
X = data.iloc[:, :1].values
y = data.iloc[:, 1].values

#To split data for Training and Testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
#randomly assigned variables 
w = 0.001
b = 0.01
L = 0.0001
iterations = 276 
n = float(len(X))
for i in range(276):
    Y_pred=w*X+b

# %%
# Calculate root mean squared error (Create a return rmse function below before testing it)
def rmse_metric(y, Y_pred):
  sum_error = 0.0
  for i in range(len(y)):
    prediction_error = Y_pred[i] - y[i]
    sum_error += (prediction_error ** 2)
  mean_error = sum_error / float(len(y))
  return sqrt(mean_error)

# %%
#Applying gradient decent
A_1 = (-2/n) * sum(X * (y - Y_pred))  
A_ = (-2/n) * sum(y - Y_pred)  
w = w - L * A_1  
b = b - L * A_ 
print (w, b)
# Out:
# [0.00233974 0.00253199 0.00246641 0.00185016 0.00251112 0.00192691
#  0.00235911 0.0020208  0.0019679  0.00192766 0.00219294 0.00217505
#  0.00242767 0.00218027 0.00202229 0.00208265 0.00209309 0.00220113
#  0.00247536 0.00200814 0.00197386 0.00170739 0.00214227 0.00257595
#  0.00223988 0.0022764  0.00208563 0.00238594 0.00213929 0.00230844
#  0.00238743 0.00188146 0.00226745 0.00243512 0.00220113 0.00224659
#  0.00206104 0.00197013 0.00211619 0.00200367 0.00200068 0.00181514
#  0.00242021 0.00198876 0.00198057 0.00238892 0.00160992 0.00198057
#  0.00189711 0.00200441 0.0018755  0.00201559 0.00188891 0.00235687
#  0.00212438 0.00185761 0.00243065 0.00209532 0.00197162 0.00164137
#  0.00175702 0.00163987 0.00206104 0.00168272 0.00194405 0.00210054
#  0.00170448 0.00184196 0.00167199 0.0019515  0.00241053 0.00166148
#  0.00228087 0.00202751 0.00191648 0.00219666 0.00200739 0.00234421
#  0.00250293 0.00195747 0.0018524  0.00199323 0.00287849 0.00242245
# ...
